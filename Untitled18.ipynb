# %%
import pandas as pd
data = {"weight":[66,67,89,76,45,71],"height":[156,165,186,165,174,167]}
bmi = pd.DataFrame(data)
bmi
# Out:
#    weight  height
# 0      66     156
# 1      67     165
# 2      89     186
# 3      76     165
# 4      45     174
# 5      71     167

# %%
#Insert new record
import numpy as np
bmi.loc[3] = [78,np.nan,np.nan]
bmi
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 3
#       1 #Insert new record
#       2 import numpy as np
# ----> 3 bmi.loc[3] = [78,np.nan,np.nan]
#       4 bmi
#
# File ~\Downloads\New folder\Lib\site-packages\pandas\core\indexing.py:911, in _LocationIndexer.__setitem__(self, key, value)
#     908 self._has_valid_setitem_indexer(key)
#     910 iloc = self if self.name == "iloc" else self.obj.iloc
# --> 911 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File ~\Downloads\New folder\Lib\site-packages\pandas\core\indexing.py:1942, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1939 # align and set the values
#    1940 if take_split_path:
#    1941     # We have to operate column-wise
# -> 1942     self._setitem_with_indexer_split_path(indexer, value, name)
#    1943 else:
# ...

# %%
bmi
# Out:
#    weight  height
# 0      66     156
# 1      67     165
# 2      89     186
# 3      76     165
# 4      45     174
# 5      71     167

# %%
import numpy as np
bmi.loc[5] = [np.nan, 65, np.nan]
bmi
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 2
#       1 import numpy as np
# ----> 2 bmi.loc[5] = [np.nan, 65, np.nan]
#       3 bmi
#
# File ~\Downloads\New folder\Lib\site-packages\pandas\core\indexing.py:911, in _LocationIndexer.__setitem__(self, key, value)
#     908 self._has_valid_setitem_indexer(key)
#     910 iloc = self if self.name == "iloc" else self.obj.iloc
# --> 911 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File ~\Downloads\New folder\Lib\site-packages\pandas\core\indexing.py:1942, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1939 # align and set the values
#    1940 if take_split_path:
#    1941     # We have to operate column-wise
# -> 1942     self._setitem_with_indexer_split_path(indexer, value, name)
#    1943 else:
#    1944     self._setitem_single_block(indexer, value, name)
#
# ...

# %%
bmi["BMI"]=bmi["weight"]/(bmi["height"]/100)**2
bmi
# Out:
#    weight  height        BMI
# 0      66     156  27.120316
# 1      67     165  24.609734
# 2      89     186  25.725517
# 3      76     165  27.915519
# 4      45     174  14.863258
# 5      71     167  25.458066

# %%
import numpy as np
bmi.loc[3] = [78,np.nan,np.nan]
bmi
# Out:
#    weight  height        BMI
# 0      66   156.0  27.120316
# 1      67   165.0  24.609734
# 2      89   186.0  25.725517
# 3      78     NaN        NaN
# 4      45   174.0  14.863258
# 5      71   167.0  25.458066

# %%
import numpy as np
bmi.loc[5] = [np.nan, 65, np.nan]
bmi
# Out:
#    weight  height        BMI
# 0    66.0   156.0  27.120316
# 1    67.0   165.0  24.609734
# 2    89.0   186.0  25.725517
# 3    78.0     NaN        NaN
# 4    45.0   174.0  14.863258
# 5     NaN    65.0        NaN

# %%
bmi.isnull().sum()
# Out:
# weight    1
# height    1
# BMI       2
# dtype: int64

# %%
bmi["height"] = bmi["height"].fillna(165)
bmi
# Out:
#    weight  height        BMI
# 0    66.0   156.0  27.120316
# 1    67.0   165.0  24.609734
# 2    89.0   186.0  25.725517
# 3    78.0   165.0        NaN
# 4    45.0   174.0  14.863258
# 5     NaN    65.0        NaN

# %%
bmi["weight"] = bmi["weight"].fillna(165)
bmi
# Out:
#    weight  height        BMI
# 0    66.0   156.0  27.120316
# 1    67.0   165.0  24.609734
# 2    89.0   186.0  25.725517
# 3    78.0   165.0        NaN
# 4    45.0   174.0  14.863258
# 5   165.0    65.0        NaN

# %%
import matplotlib.pyplot as plt
plt.hist(iris_df["sepal.length"], color="blue
